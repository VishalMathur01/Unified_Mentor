# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
basic_info = pd.read_excel("/content/Entertainer - Basic Info.xlsx")
breakthrough_info = pd.read_excel("/content/Entertainer - Breakthrough Info.xlsx")
last_work_info = pd.read_excel("/content/Entertainer - Last work Info.xlsx")

# %% [markdown]
# # EDA

# %%
basic_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entertainer           70 non-null     object
#  1   Gender (traditional)  70 non-null     object
#  2   Birth Year            70 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.8+ KB

# %%
basic_info.describe()
# Out:
#         Birth Year
# count    70.000000
# mean   1935.585714
# std      24.135783
# min    1889.000000
# 25%    1916.000000
# 50%    1935.500000
# 75%    1954.000000
# max    1988.000000

# %%
basic_info.head(10)
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
# 5      Bing Crosby                    M        1903
# 6         Bob Hope                    M        1903
# 7    Carol Burnett                    F        1933
# 8   Carole Lombard                    F        1908
# 9    Carrie Fisher                    F        1956

# %%
basic_info.groupby('Gender (traditional)').size().plot(kind='barh')
# Out:
# <Axes: ylabel='Gender (traditional)'>

# %%
basic_info['Birth Year'].plot(kind='hist', title='Birth Year')
# Out:
# <Axes: title={'center': 'Birth Year'}, ylabel='Frequency'>

# %%
breakthrough_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 4 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Entertainer                                   70 non-null     object
#  1   Year of Breakthrough/#1 Hit/Award Nomination  70 non-null     int64
#  2   Breakthrough Name                             70 non-null     object
#  3   Year of First Oscar/Grammy/Emmy               64 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.3+ KB

# %%
breakthrough_info.describe()
# Out:
#        Year of Breakthrough/#1 Hit/Award Nomination  \
# count                                     70.000000
# mean                                    1964.228571
# std                                       22.411935
# min                                     1915.000000
# 25%                                     1949.500000
# 50%                                     1963.500000
# 75%                                     1983.500000
# max                                     2008.000000
#
#        Year of First Oscar/Grammy/Emmy
# count                        64.000000
# mean                       1976.234375
# std                          22.170152
# min                        1929.000000
# 25%                        1962.000000
# 50%                        1978.000000
# 75%                        1993.000000
# max                        2017.000000

# %%
breakthrough_info.head(10)
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
# 5      Bing Crosby                                          1931
# 6         Bob Hope                                          1938
# 7    Carol Burnett                                          1959
# 8   Carole Lombard                                          1934
# 9    Carrie Fisher                                          1977
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
sns.pairplot(breakthrough_info)

# %%
breakthrough_info.plot(kind='scatter', x='Year of Breakthrough/#1 Hit/Award Nomination', y='Year of First Oscar/Grammy/Emmy', s=32, alpha=.8)
# Out:
# <Axes: xlabel='Year of Breakthrough/#1 Hit/Award Nomination', ylabel='Year of First Oscar/Grammy/Emmy'>

# %%
last_work_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Entertainer                         70 non-null     object
#  1   Year of Last Major Work (arguable)  70 non-null     int64
#  2   Year of Death                       30 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.8+ KB

# %%
last_work_info.describe()
# Out:
#        Year of Last Major Work (arguable)  Year of Death
# count                           70.000000      30.000000
# mean                          1998.971429    1988.133333
# std                             22.874561      20.483355
# min                           1933.000000    1942.000000
# 25%                           1980.000000    1977.000000
# 50%                           2014.000000    1989.500000
# 75%                           2016.000000    2003.750000
# max                           2016.000000    2016.000000

# %%
last_work_info.head(10)
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN
# 5      Bing Crosby                                1974         1977.0
# 6         Bob Hope                                1972         2003.0
# 7    Carol Burnett                                2016            NaN
# 8   Carole Lombard                                1942         1942.0
# 9    Carrie Fisher                                2016         2016.0

# %%
sns.pairplot(last_work_info)
